# %% [markdown]
# <a href="https://colab.research.google.com/github/Miladpolytechnique/cat-dog/blob/master/cat_dog_milad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%autoreload 2

#%matplotlib inline

# %%
import math
import time
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
from PIL import Image
from sklearn.metrics import confusion_matrix
from torchsummary import summary
from torch.autograd import Variable

np.set_printoptions(precision=2)
np.random.seed(1234)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.utils.data.sampler as sampler

use_gpu = torch.cuda.is_available()

# %%
import torchvision
import torchvision.datasets as dataset
import torchvision.models as models
import torchvision.transforms as transforms

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
# Hyper parameters
Data_DIR = "/drive/My Drive/cat-dog/"
Image_size = 224 # size of each img
batch_size = 256 # 25 ta ax midam vase train

# %%
os.listdir(Data_DIR)
# Out:
# ['testset', 'trainset']

# %%
trn_dir = f'{Data_DIR}trainset'  #make string my train dataset
tst_dir = f'{Data_DIR}testset'   # make string my validation dataset

# %%
print(os.listdir(trn_dir))
print(os.listdir(tst_dir))
# Out:
# ['Cat', 'Dog', '.DS_Store']
# ['test', '.DS_Store']

# %%
# use glob library to address my img
trn_fname = glob.glob(f'{trn_dir}/*/*.jpg')  # use glob to see where is my trainset and I mentioned which files I want!!!
trn_fname[:5]
# Out:
# ['/drive/My Drive/cat-dog/trainset/Cat/2506.Cat.jpg',
#  '/drive/My Drive/cat-dog/trainset/Cat/6752.Cat.jpg',
#  '/drive/My Drive/cat-dog/trainset/Cat/5540.Cat.jpg',
#  '/drive/My Drive/cat-dog/trainset/Cat/3174.Cat.jpg',
#  '/drive/My Drive/cat-dog/trainset/Cat/6742.Cat.jpg']

# %%
img = plt.imread(trn_fname[1])
plt.imshow(img)

# %%
#Data processing
# resize the image to uniqe one and transfor it to tensor
tfms = transforms.Compose([
    transforms.Resize((Image_size, Image_size)), 
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), # Tensor or matrix
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # RGB ,normlzie all imgs,to use in my mean and sd
])

# %%
#Apply transformation
train_ds = dataset.ImageFolder(trn_dir, transform=tfms)
test_ds = dataset.ImageFolder(tst_dir, transform=tfms)
train_ds.class_to_idx
# Out:
# {'Cat': 0, 'Dog': 1}

# %%
#Split data into training and validation
TRAIN_SIZE = int(len(train_ds.imgs) *0.8)
VALID_SIZE = len(train_ds.imgs) - TRAIN_SIZE

indices = list(range(len(train_ds.imgs)))
np.random.seed(123)
np.random.shuffle(indices)

train_idx, valid_idx = indices[:TRAIN_SIZE], indices[TRAIN_SIZE:]

train_sampler = sampler.SubsetRandomSampler(train_idx)
valid_sampler = sampler.SubsetRandomSampler(valid_idx)

train_dl = torch.utils.data.DataLoader(
    train_ds, batch_size=batch_size, sampler=train_sampler, num_workers=8)

valid_dl = torch.utils.data.DataLoader(
    train_ds, batch_size=batch_size,  sampler=valid_sampler, num_workers=8)

test_dl = torch.utils.data.DataLoader(
    test_ds, batch_size=batch_size,num_workers=8)

# %%
print("Summary:")
print('Size train Dataset:',len(train_dl)*batch_size)
print('Size validation:',len(valid_dl)*batch_size)
print('Test images:',len(test_ds))
print('Image size:', train_ds[0][0].size())
# Out:
# Summary:
# Size train Dataset: 16128
# Size validation: 4096
# Test images: 4999
# Image size: torch.Size([3, 224, 224])

# %%
inputs, targets = next(iter(train_dl)) # there is an object (train_dl) that we can make itration, it take 16 imgs
out = torchvision.utils.make_grid(inputs, padding=3) # khoshgel bechinam beside eachother LOL

plt.figure(figsize=(16, 12));

# %%
def imshow(inp, title=None):
    """Imshow for Tensor.
    """
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    plt.axis('off')
    if title is not None:
        plt.title(title)

# %%
imshow(out, title='Random images from training data')

# %%
# class VGG(nn.Module):
    
#     def __init__(self): # __init__ is constructor 
#         super(VGG, self).__init__()
        
#         self.layer1 = nn.Sequential(
#             nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2, stride=2)
#         )

#         self.layer2 = nn.Sequential(
#             nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2, stride=2)
#         )
        
#         self.layer3 = nn.Sequential(
#             nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.Conv2d(in_channels=256, out_channels=256, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2, stride=2)
#         )
        
#         self.layer4 = nn.Sequential(
#             nn.Conv2d(in_channels=256, out_channels=512, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2, stride=2)
#         )
        
#         self.layer5 = nn.Sequential(
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.Conv2d(in_channels=512, out_channels=512, kernel_size=(3, 3),
#             stride=1, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2, stride=2)
#         )
        
        
#         self.fc = nn.Sequential(
#             nn.Linear(512*7*7, 4096),
#             nn.ReLU(),
#             nn.Linear(4096, 4096),
#             nn.ReLU(),
#             nn.Linear(4096, 1000),
#             nn.ReLU(),
#             nn.Linear(1000, 2),
#             nn.Softmax()
#         )
        
#     def forward(self, x):
#         out = self.layer1(x)
#         out = self.layer2(out)            
#         out = self.layer3(out)
#         out = self.layer4(out)
#         out = self.layer5(out)
#         out = out.view(out.size(0), -1) 
#         out = self.fc(out)
        
#         return out

class SimpleCNN(nn.Module):
    
    def __init__(self): # __init__ is constructor 
        super(SimpleCNN, self).__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16,  kernel_size=(3, 3),stride=1, padding=1), # 3 = RGB(3channal), 16= 16 filter, padding= reduce the sie 1 column and rows
            nn.ReLU(), # nonlinear AF, - make 0
            nn.MaxPool2d(2, stride=2)
        )
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32,   kernel_size=(3, 3),stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, stride=2)
        )
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(32, 64,  kernel_size=(3, 3),stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, stride=2)
        )
        
        self.fc =  nn.Sequential(
            nn.Linear(28 * 28 * 64, 500), # fully connected layer, in pytorch we call linear layer, make the all layer to 2 vector (0,1)
            nn.ReLU(),
            nn.Linear(500, 2),
            nn.Softmax()
        )
    def forward(self, x):
        out = self.conv1(x)
        out = self.conv2(out)             # (bs, C, H, W)
        out = self.conv3(out)
#         print(out.size())
        out = out.view(out.size(0), -1)  #(bs, C, H, W)
        out = self.fc(out)
        
        return out

# %%
cuda_available = torch.cuda.is_available()

# %%
#  run
model = SimpleCNN()
model.cuda()
summary(model, (3, 224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 224, 224]             448
#               ReLU-2         [-1, 16, 224, 224]               0
#          MaxPool2d-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]           4,640
#               ReLU-5         [-1, 32, 112, 112]               0
#          MaxPool2d-6           [-1, 32, 56, 56]               0
#             Conv2d-7           [-1, 64, 56, 56]          18,496
#               ReLU-8           [-1, 64, 56, 56]               0
#          MaxPool2d-9           [-1, 64, 28, 28]               0
#            Linear-10                  [-1, 500]      25,088,500
#              ReLU-11                  [-1, 500]               0
#            Linear-12                    [-1, 2]           1,002
#           Softmax-13                    [-1, 2]               0
# ================================================================
# Total params: 25,113,086
# Trainable params: 25,113,086
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 24.12
# Params size (MB): 95.80
# Estimated Total Size (MB): 120.50
# ----------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
if cuda_available:
    model = model.cuda()
#Loss function and 
criterion = nn.CrossEntropyLoss() # minimize this 
optimizer = optim.SGD(model.parameters(), lr=0.01) # stochastic gradien, W = W - lr * dW

# %%
def to_var(x):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x)

# %%
# for epoch in range(10):
#     losses = []
#     # Train
#     for batch_idx, (inputs, targets) in enumerate(train_dl):
#         if cuda_available:
#             inputs, targets = inputs.cuda(), targets.cuda()

#         optimizer.zero_grad()
#         inputs, targets = Variable(inputs), Variable(targets)
#         outputs = model(inputs)
#         loss = criterion(outputs, targets)
#         loss.backward()
#         optimizer.step()
#         losses.append(loss.item())

#     print('Epoch : %d Loss : %.3f ' % (epoch, np.mean(losses)))
    
#     # Evaluate
#     model.eval()
#     total = 0
#     correct = 0
#     for batch_idx, (inputs, targets) in enumerate(test_dl):
#         if cuda_available:
#             inputs, targets = inputs.cuda(), targets.cuda()

#         inputs, targets = Variable(inputs, volatile=True), Variable(targets, volatile=True)
#         outputs = model(inputs)
#         _, predicted = torch.max(outputs.data, 1)
#         total += targets.size(0)
#         correct += predicted.eq(targets.data).cpu().sum()

#     print('Epoch : %d Test Acc : %.3f' % (epoch, 100.*correct/total))
#     print('--------------------------------------------------------------')
#     model.train()

# %%
#Train
num_epochs = 50
losses = []
epoch_losses = []
for epoch in range(num_epochs):
    for i, (inputs, targets) in enumerate(train_dl):
        inputs = to_var(inputs)
        targets = to_var(targets)
                
        # forward
        optimizer.zero_grad()
        outputs = model(inputs)
        
        # loss
        loss = criterion(outputs, targets)
        losses += [loss.item()] # draw fig
        
        # loos backward
        loss.backward()
        
        #update params
        optimizer.step()
        
        #report
        print ('Epoch [%2d/%3d], Step [%3d/%3d], Loss: %.4f' 
                   % (epoch + 1, num_epochs, i + 1, len(train_ds) // batch_size, loss.item()))
    epoch_losses.append(np.mean(losses))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch [ 1/ 50], Step [  1/ 78], Loss: 0.6939
# Epoch [ 1/ 50], Step [  2/ 78], Loss: 0.6934
# Epoch [ 1/ 50], Step [  3/ 78], Loss: 0.6932
# Epoch [ 1/ 50], Step [  4/ 78], Loss: 0.6927
# Epoch [ 1/ 50], Step [  5/ 78], Loss: 0.6933
# Epoch [ 1/ 50], Step [  6/ 78], Loss: 0.6932
# Epoch [ 1/ 50], Step [  7/ 78], Loss: 0.6932
# Epoch [ 1/ 50], Step [  8/ 78], Loss: 0.6932
# Epoch [ 1/ 50], Step [  9/ 78], Loss: 0.6931
# Epoch [ 1/ 50], Step [ 10/ 78], Loss: 0.6926
# Epoch [ 1/ 50], Step [ 11/ 78], Loss: 0.6924
# Epoch [ 1/ 50], Step [ 12/ 78], Loss: 0.6934
# Epoch [ 1/ 50], Step [ 13/ 78], Loss: 0.6926
# Epoch [ 1/ 50], Step [ 14/ 78], Loss: 0.6921
# Epoch [ 1/ 50], Step [ 15/ 78], Loss: 0.6924
# Epoch [ 1/ 50], Step [ 16/ 78], Loss: 0.6916
# Epoch [ 1/ 50], Step [ 17/ 78], Loss: 0.6945
# Epoch [ 1/ 50], Step [ 18/ 78], Loss: 0.6928
# Epoch [ 1/ 50], Step [ 19/ 78], Loss: 0.6921
# Epoch [ 1/ 50], Step [ 20/ 78], Loss: 0.6918
# Epoch [ 1/ 50], Step [ 21/ 78], Loss: 0.6928
# Epoch [ 1/ 50], Step [ 22/ 78], Loss: 0.6918
# Epoch [ 1/ 50], Step [ 23/ 78], Loss: 0.6929
# Epoch [ 1/ 50], Step [ 24/ 78], Loss: 0.6916
# Epoch [ 1/ 50], Step [ 25/ 78], Loss: 0.6927
# Epoch [ 1/ 50], Step [ 26/ 78], Loss: 0.6911
# Epoch [ 1/ 50], Step [ 27/ 78], Loss: 0.6920
# Epoch [ 1/ 50], Step [ 28/ 78], Loss: 0.6923
# Epoch [ 1/ 50], Step [ 29/ 78], Loss: 0.6913
# Epoch [ 1/ 50], Step [ 30/ 78], Loss: 0.6911
# Epoch [ 1/ 50], Step [ 31/ 78], Loss: 0.6914
# Epoch [ 1/ 50], Step [ 32/ 78], Loss: 0.6918
# Epoch [ 1/ 50], Step [ 33/ 78], Loss: 0.6927
# Epoch [ 1/ 50], Step [ 34/ 78], Loss: 0.6904
# Epoch [ 1/ 50], Step [ 35/ 78], Loss: 0.6912
# Epoch [ 1/ 50], Step [ 36/ 78], Loss: 0.6896
# Epoch [ 1/ 50], Step [ 37/ 78], Loss: 0.6891
# Epoch [ 1/ 50], Step [ 38/ 78], Loss: 0.6925
# Epoch [ 1/ 50], Step [ 39/ 78], Loss: 0.6907
# Epoch [ 1/ 50], Step [ 40/ 78], Loss: 0.6906
# Epoch [ 1/ 50], Step [ 41/ 78], Loss: 0.6905
# Epoch [ 1/ 50], Step [ 42/ 78], Loss: 0.6920
# Epoch [ 1/ 50], Step [ 43/ 78], Loss: 0.6928
# Epoch [ 1/ 50], Step [ 44/ 78], Loss: 0.6896
# Epoch [ 1/ 50], Step [ 45/ 78], Loss: 0.6906
# Epoch [ 1/ 50], Step [ 46/ 78], Loss: 0.6898
# Epoch [ 1/ 50], Step [ 47/ 78], Loss: 0.6918
# Epoch [ 1/ 50], Step [ 48/ 78], Loss: 0.6911
# Epoch [ 1/ 50], Step [ 49/ 78], Loss: 0.6930
# Epoch [ 1/ 50], Step [ 50/ 78], Loss: 0.6903
# Epoch [ 1/ 50], Step [ 51/ 78], Loss: 0.6910
# Epoch [ 1/ 50], Step [ 52/ 78], Loss: 0.6899
# Epoch [ 1/ 50], Step [ 53/ 78], Loss: 0.6893
# Epoch [ 1/ 50], Step [ 54/ 78], Loss: 0.6891
# Epoch [ 1/ 50], Step [ 55/ 78], Loss: 0.6907
# Epoch [ 1/ 50], Step [ 56/ 78], Loss: 0.6886
# Epoch [ 1/ 50], Step [ 57/ 78], Loss: 0.6869
# Epoch [ 1/ 50], Step [ 58/ 78], Loss: 0.6927
# Epoch [ 1/ 50], Step [ 59/ 78], Loss: 0.6884
# Epoch [ 1/ 50], Step [ 60/ 78], Loss: 0.6927
# Epoch [ 1/ 50], Step [ 61/ 78], Loss: 0.6914
# Epoch [ 1/ 50], Step [ 62/ 78], Loss: 0.6882
# Epoch [ 1/ 50], Step [ 63/ 78], Loss: 0.6846
# Epoch [ 2/ 50], Step [  1/ 78], Loss: 0.6887
# Epoch [ 2/ 50], Step [  2/ 78], Loss: 0.6853
# Epoch [ 2/ 50], Step [  3/ 78], Loss: 0.6894
# Epoch [ 2/ 50], Step [  4/ 78], Loss: 0.6865
# Epoch [ 2/ 50], Step [  5/ 78], Loss: 0.6880
# Epoch [ 2/ 50], Step [  6/ 78], Loss: 0.6900
# Epoch [ 2/ 50], Step [  7/ 78], Loss: 0.6867
# Epoch [ 2/ 50], Step [  8/ 78], Loss: 0.6889
# Epoch [ 2/ 50], Step [  9/ 78], Loss: 0.6926
# Epoch [ 2/ 50], Step [ 10/ 78], Loss: 0.6849
# Epoch [ 2/ 50], Step [ 11/ 78], Loss: 0.6895
# Epoch [ 2/ 50], Step [ 12/ 78], Loss: 0.6900
# Epoch [ 2/ 50], Step [ 13/ 78], Loss: 0.6926
# Epoch [ 2/ 50], Step [ 14/ 78], Loss: 0.6882
# Epoch [ 2/ 50], Step [ 15/ 78], Loss: 0.6895
# Epoch [ 2/ 50], Step [ 16/ 78], Loss: 0.6881
# Epoch [ 2/ 50], Step [ 17/ 78], Loss: 0.6863
# Epoch [ 2/ 50], Step [ 18/ 78], Loss: 0.6870
# Epoch [ 2/ 50], Step [ 19/ 78], Loss: 0.6897
# Epoch [ 2/ 50], Step [ 20/ 78], Loss: 0.6873
# Epoch [ 2/ 50], Step [ 21/ 78], Loss: 0.6893
# Epoch [ 2/ 50], Step [ 22/ 78], Loss: 0.6890
# Epoch [ 2/ 50], Step [ 23/ 78], Loss: 0.6892
# Epoch [ 2/ 50], Step [ 24/ 78], Loss: 0.6881
# Epoch [ 2/ 50], Step [ 25/ 78], Loss: 0.6869
# Epoch [ 2/ 50], Step [ 26/ 78], Loss: 0.6865
# Epoch [ 2/ 50], Step [ 27/ 78], Loss: 0.6901
# Epoch [ 2/ 50], Step [ 28/ 78], Loss: 0.6874
# Epoch [ 2/ 50], Step [ 29/ 78], Loss: 0.6872
# Epoch [ 2/ 50], Step [ 30/ 78], Loss: 0.6891
# Epoch [ 2/ 50], Step [ 31/ 78], Loss: 0.6921
# Epoch [ 2/ 50], Step [ 32/ 78], Loss: 0.6891
# Epoch [ 2/ 50], Step [ 33/ 78], Loss: 0.6843
# Epoch [ 2/ 50], Step [ 34/ 78], Loss: 0.6884
# Epoch [ 2/ 50], Step [ 35/ 78], Loss: 0.6901
# Epoch [ 2/ 50], Step [ 36/ 78], Loss: 0.6878
# Epoch [ 2/ 50], Step [ 37/ 78], Loss: 0.6861
# Epoch [ 2/ 50], Step [ 38/ 78], Loss: 0.6880
# Epoch [ 2/ 50], Step [ 39/ 78], Loss: 0.6871
# Epoch [ 2/ 50], Step [ 40/ 78], Loss: 0.6870
# Epoch [ 2/ 50], Step [ 41/ 78], Loss: 0.6869
# Epoch [ 2/ 50], Step [ 42/ 78], Loss: 0.6896
# Epoch [ 2/ 50], Step [ 43/ 78], Loss: 0.6845
# Epoch [ 2/ 50], Step [ 44/ 78], Loss: 0.6838
# Epoch [ 2/ 50], Step [ 45/ 78], Loss: 0.6900
# Epoch [ 2/ 50], Step [ 46/ 78], Loss: 0.6847
# Epoch [ 2/ 50], Step [ 47/ 78], Loss: 0.6870
# Epoch [ 2/ 50], Step [ 48/ 78], Loss: 0.6863
# Epoch [ 2/ 50], Step [ 49/ 78], Loss: 0.6840
# Epoch [ 2/ 50], Step [ 50/ 78], Loss: 0.6887
# Epoch [ 2/ 50], Step [ 51/ 78], Loss: 0.6860
# Epoch [ 2/ 50], Step [ 52/ 78], Loss: 0.6826
# Epoch [ 2/ 50], Step [ 53/ 78], Loss: 0.6843
# Epoch [ 2/ 50], Step [ 54/ 78], Loss: 0.6832
# Epoch [ 2/ 50], Step [ 55/ 78], Loss: 0.6854
# Epoch [ 2/ 50], Step [ 56/ 78], Loss: 0.6828
# Epoch [ 2/ 50], Step [ 57/ 78], Loss: 0.6827
# Epoch [ 2/ 50], Step [ 58/ 78], Loss: 0.6877
# Epoch [ 2/ 50], Step [ 59/ 78], Loss: 0.6907
# Epoch [ 2/ 50], Step [ 60/ 78], Loss: 0.6862
# Epoch [ 2/ 50], Step [ 61/ 78], Loss: 0.6870
# Epoch [ 2/ 50], Step [ 62/ 78], Loss: 0.6880
# Epoch [ 2/ 50], Step [ 63/ 78], Loss: 0.6896
# Epoch [ 3/ 50], Step [  1/ 78], Loss: 0.6866
# Epoch [ 3/ 50], Step [  2/ 78], Loss: 0.6865
# Epoch [ 3/ 50], Step [  3/ 78], Loss: 0.6806
# Epoch [ 3/ 50], Step [  4/ 78], Loss: 0.6871
# Epoch [ 3/ 50], Step [  5/ 78], Loss: 0.6893
# Epoch [ 3/ 50], Step [  6/ 78], Loss: 0.6800
# Epoch [ 3/ 50], Step [  7/ 78], Loss: 0.6815
# Epoch [ 3/ 50], Step [  8/ 78], Loss: 0.6882
# Epoch [ 3/ 50], Step [  9/ 78], Loss: 0.6772
# Epoch [ 3/ 50], Step [ 10/ 78], Loss: 0.6831
# Epoch [ 3/ 50], Step [ 11/ 78], Loss: 0.6826
# Epoch [ 3/ 50], Step [ 12/ 78], Loss: 0.6791
# Epoch [ 3/ 50], Step [ 13/ 78], Loss: 0.6823
# Epoch [ 3/ 50], Step [ 14/ 78], Loss: 0.6842
# Epoch [ 3/ 50], Step [ 15/ 78], Loss: 0.6755
# Epoch [ 3/ 50], Step [ 16/ 78], Loss: 0.6832
# Epoch [ 3/ 50], Step [ 17/ 78], Loss: 0.6793
# Epoch [ 3/ 50], Step [ 18/ 78], Loss: 0.6781
# Epoch [ 3/ 50], Step [ 19/ 78], Loss: 0.6871
# Epoch [ 3/ 50], Step [ 20/ 78], Loss: 0.6831
# Epoch [ 3/ 50], Step [ 21/ 78], Loss: 0.6868
# Epoch [ 3/ 50], Step [ 22/ 78], Loss: 0.6851
# Epoch [ 4/ 50], Step [  4/ 78], Loss: 0.6817
# Epoch [ 4/ 50], Step [  5/ 78], Loss: 0.6766
# Epoch [ 4/ 50], Step [  6/ 78], Loss: 0.6827
# Epoch [ 4/ 50], Step [  7/ 78], Loss: 0.6830
# Epoch [ 4/ 50], Step [  8/ 78], Loss: 0.6835
# Epoch [ 4/ 50], Step [  9/ 78], Loss: 0.6848
# Epoch [ 4/ 50], Step [ 10/ 78], Loss: 0.6720
# Epoch [ 4/ 50], Step [ 11/ 78], Loss: 0.6823
# Epoch [ 4/ 50], Step [ 12/ 78], Loss: 0.6915
# Epoch [ 4/ 50], Step [ 13/ 78], Loss: 0.6825
# Epoch [ 4/ 50], Step [ 14/ 78], Loss: 0.6787
# Epoch [ 4/ 50], Step [ 15/ 78], Loss: 0.6785
# Epoch [ 4/ 50], Step [ 16/ 78], Loss: 0.6902
# Epoch [ 4/ 50], Step [ 17/ 78], Loss: 0.6840
# Epoch [ 4/ 50], Step [ 18/ 78], Loss: 0.6747
# Epoch [ 4/ 50], Step [ 19/ 78], Loss: 0.6798
# Epoch [ 4/ 50], Step [ 20/ 78], Loss: 0.6830
# Epoch [ 4/ 50], Step [ 21/ 78], Loss: 0.6790
# Epoch [ 4/ 50], Step [ 22/ 78], Loss: 0.6815
# Epoch [ 4/ 50], Step [ 23/ 78], Loss: 0.6789
# Epoch [ 4/ 50], Step [ 24/ 78], Loss: 0.6620
# Epoch [ 4/ 50], Step [ 25/ 78], Loss: 0.6826
# Epoch [ 4/ 50], Step [ 26/ 78], Loss: 0.6763
# Epoch [ 4/ 50], Step [ 27/ 78], Loss: 0.6685
# Epoch [ 4/ 50], Step [ 28/ 78], Loss: 0.6735
# Epoch [ 4/ 50], Step [ 29/ 78], Loss: 0.6749
# Epoch [ 4/ 50], Step [ 30/ 78], Loss: 0.6775
# Epoch [ 4/ 50], Step [ 31/ 78], Loss: 0.6819
# Epoch [ 4/ 50], Step [ 32/ 78], Loss: 0.6831
# Epoch [ 4/ 50], Step [ 33/ 78], Loss: 0.6772
# Epoch [ 4/ 50], Step [ 34/ 78], Loss: 0.6858
# Epoch [ 4/ 50], Step [ 35/ 78], Loss: 0.6793
# Epoch [ 4/ 50], Step [ 36/ 78], Loss: 0.6765
# Epoch [ 4/ 50], Step [ 37/ 78], Loss: 0.6890
# Epoch [ 4/ 50], Step [ 38/ 78], Loss: 0.6808
# Epoch [ 4/ 50], Step [ 39/ 78], Loss: 0.6850
# Epoch [ 4/ 50], Step [ 40/ 78], Loss: 0.6850
# Epoch [ 4/ 50], Step [ 41/ 78], Loss: 0.6892
# Epoch [ 4/ 50], Step [ 42/ 78], Loss: 0.6718
# Epoch [ 4/ 50], Step [ 43/ 78], Loss: 0.6701
# Epoch [ 4/ 50], Step [ 44/ 78], Loss: 0.6852
# Epoch [ 4/ 50], Step [ 45/ 78], Loss: 0.6772
# Epoch [ 4/ 50], Step [ 46/ 78], Loss: 0.6847
# Epoch [ 4/ 50], Step [ 47/ 78], Loss: 0.6768
# Epoch [ 4/ 50], Step [ 48/ 78], Loss: 0.6778
# Epoch [ 4/ 50], Step [ 49/ 78], Loss: 0.6695
# Epoch [ 4/ 50], Step [ 50/ 78], Loss: 0.6733
# Epoch [ 4/ 50], Step [ 51/ 78], Loss: 0.6812
# Epoch [ 4/ 50], Step [ 52/ 78], Loss: 0.6813
# Epoch [ 4/ 50], Step [ 53/ 78], Loss: 0.6749
# Epoch [ 4/ 50], Step [ 54/ 78], Loss: 0.6722
# Epoch [ 4/ 50], Step [ 55/ 78], Loss: 0.6751
# Epoch [ 4/ 50], Step [ 56/ 78], Loss: 0.6765
# Epoch [ 4/ 50], Step [ 57/ 78], Loss: 0.6722
# Epoch [ 4/ 50], Step [ 58/ 78], Loss: 0.6853
# Epoch [ 4/ 50], Step [ 59/ 78], Loss: 0.6930
# Epoch [ 4/ 50], Step [ 60/ 78], Loss: 0.6817
# Epoch [ 4/ 50], Step [ 61/ 78], Loss: 0.6819
# Epoch [ 4/ 50], Step [ 62/ 78], Loss: 0.6582
# Epoch [ 4/ 50], Step [ 63/ 78], Loss: 0.6746
# Epoch [ 5/ 50], Step [  1/ 78], Loss: 0.6767
# Epoch [ 5/ 50], Step [  2/ 78], Loss: 0.6817
# Epoch [ 5/ 50], Step [  3/ 78], Loss: 0.6718
# Epoch [ 5/ 50], Step [  4/ 78], Loss: 0.6688
# Epoch [ 5/ 50], Step [  5/ 78], Loss: 0.6804
# Epoch [ 5/ 50], Step [  6/ 78], Loss: 0.6762
# Epoch [ 5/ 50], Step [  7/ 78], Loss: 0.6796
# Epoch [ 5/ 50], Step [  8/ 78], Loss: 0.6753
# Epoch [ 5/ 50], Step [  9/ 78], Loss: 0.6765
# Epoch [ 5/ 50], Step [ 10/ 78], Loss: 0.6762
# Epoch [ 5/ 50], Step [ 11/ 78], Loss: 0.6771
# Epoch [ 5/ 50], Step [ 12/ 78], Loss: 0.6671
# Epoch [ 5/ 50], Step [ 13/ 78], Loss: 0.6678
# Epoch [ 5/ 50], Step [ 14/ 78], Loss: 0.6684
# Epoch [ 5/ 50], Step [ 15/ 78], Loss: 0.6756
# Epoch [ 5/ 50], Step [ 16/ 78], Loss: 0.6722
# Epoch [ 5/ 50], Step [ 17/ 78], Loss: 0.6823
# Epoch [ 5/ 50], Step [ 18/ 78], Loss: 0.6733
# Epoch [ 5/ 50], Step [ 19/ 78], Loss: 0.6737
# Epoch [ 5/ 50], Step [ 20/ 78], Loss: 0.6835
# Epoch [ 5/ 50], Step [ 21/ 78], Loss: 0.6903
# Epoch [ 5/ 50], Step [ 22/ 78], Loss: 0.6784
# Epoch [ 5/ 50], Step [ 23/ 78], Loss: 0.6729
# Epoch [ 5/ 50], Step [ 24/ 78], Loss: 0.6776
# Epoch [ 5/ 50], Step [ 25/ 78], Loss: 0.6731
# Epoch [ 5/ 50], Step [ 26/ 78], Loss: 0.6912
# Epoch [ 5/ 50], Step [ 27/ 78], Loss: 0.6756
# Epoch [ 5/ 50], Step [ 28/ 78], Loss: 0.6722
# Epoch [ 5/ 50], Step [ 29/ 78], Loss: 0.6862
# Epoch [ 5/ 50], Step [ 30/ 78], Loss: 0.6764
# Epoch [ 5/ 50], Step [ 31/ 78], Loss: 0.6833
# Epoch [ 5/ 50], Step [ 32/ 78], Loss: 0.6648
# Epoch [ 5/ 50], Step [ 33/ 78], Loss: 0.6584
# Epoch [ 5/ 50], Step [ 34/ 78], Loss: 0.6793
# Epoch [ 5/ 50], Step [ 35/ 78], Loss: 0.6806
# Epoch [ 5/ 50], Step [ 36/ 78], Loss: 0.6707
# Epoch [ 5/ 50], Step [ 37/ 78], Loss: 0.6759
# Epoch [ 5/ 50], Step [ 38/ 78], Loss: 0.6714
# Epoch [ 5/ 50], Step [ 39/ 78], Loss: 0.6744
# Epoch [ 5/ 50], Step [ 40/ 78], Loss: 0.6673
# Epoch [ 5/ 50], Step [ 41/ 78], Loss: 0.6828
# Epoch [ 5/ 50], Step [ 42/ 78], Loss: 0.6691
# Epoch [ 5/ 50], Step [ 43/ 78], Loss: 0.6767
# Epoch [ 5/ 50], Step [ 44/ 78], Loss: 0.6787
# Epoch [ 5/ 50], Step [ 45/ 78], Loss: 0.6947
# Epoch [ 5/ 50], Step [ 46/ 78], Loss: 0.6783
# Epoch [ 5/ 50], Step [ 47/ 78], Loss: 0.6696
# Epoch [ 5/ 50], Step [ 48/ 78], Loss: 0.6694
# Epoch [ 5/ 50], Step [ 49/ 78], Loss: 0.6745
# Epoch [ 5/ 50], Step [ 50/ 78], Loss: 0.6923
# Epoch [ 5/ 50], Step [ 51/ 78], Loss: 0.6708
# Epoch [ 5/ 50], Step [ 52/ 78], Loss: 0.6786
# Epoch [ 5/ 50], Step [ 53/ 78], Loss: 0.6729
# Epoch [ 5/ 50], Step [ 54/ 78], Loss: 0.6816
# Epoch [ 5/ 50], Step [ 55/ 78], Loss: 0.6639
# Epoch [ 5/ 50], Step [ 56/ 78], Loss: 0.6719
# Epoch [ 5/ 50], Step [ 57/ 78], Loss: 0.6729
# Epoch [ 5/ 50], Step [ 58/ 78], Loss: 0.6662
# Epoch [ 5/ 50], Step [ 59/ 78], Loss: 0.6649
# Epoch [ 5/ 50], Step [ 60/ 78], Loss: 0.6677
# Epoch [ 5/ 50], Step [ 61/ 78], Loss: 0.6718
# Epoch [ 5/ 50], Step [ 62/ 78], Loss: 0.6770
# Epoch [ 5/ 50], Step [ 63/ 78], Loss: 0.6637
# Epoch [ 6/ 50], Step [  1/ 78], Loss: 0.6912
# Epoch [ 6/ 50], Step [  2/ 78], Loss: 0.6830
# Epoch [ 6/ 50], Step [  3/ 78], Loss: 0.6794
# Epoch [ 6/ 50], Step [  4/ 78], Loss: 0.6668
# Epoch [ 6/ 50], Step [  5/ 78], Loss: 0.6502
# Epoch [ 6/ 50], Step [  6/ 78], Loss: 0.6867
# Epoch [ 6/ 50], Step [  7/ 78], Loss: 0.6750
# Epoch [ 6/ 50], Step [  8/ 78], Loss: 0.6822
# Epoch [ 6/ 50], Step [  9/ 78], Loss: 0.6715
# Epoch [ 6/ 50], Step [ 10/ 78], Loss: 0.6559
# Epoch [ 6/ 50], Step [ 11/ 78], Loss: 0.6709
# Epoch [ 6/ 50], Step [ 12/ 78], Loss: 0.6735
# Epoch [ 6/ 50], Step [ 13/ 78], Loss: 0.6751
# Epoch [ 6/ 50], Step [ 14/ 78], Loss: 0.6512
# Epoch [ 6/ 50], Step [ 15/ 78], Loss: 0.6694
# Epoch [ 6/ 50], Step [ 16/ 78], Loss: 0.6730
# Epoch [ 6/ 50], Step [ 17/ 78], Loss: 0.6719
# Epoch [ 6/ 50], Step [ 18/ 78], Loss: 0.6626
# Epoch [ 6/ 50], Step [ 19/ 78], Loss: 0.6783
# Epoch [ 6/ 50], Step [ 20/ 78], Loss: 0.6746
# Epoch [ 6/ 50], Step [ 21/ 78], Loss: 0.6774
# Epoch [ 6/ 50], Step [ 22/ 78], Loss: 0.6702
# Epoch [ 6/ 50], Step [ 23/ 78], Loss: 0.6560
# Epoch [ 6/ 50], Step [ 24/ 78], Loss: 0.6681
# Epoch [ 6/ 50], Step [ 25/ 78], Loss: 0.6595
# Epoch [ 6/ 50], Step [ 26/ 78], Loss: 0.6570
# Epoch [ 6/ 50], Step [ 27/ 78], Loss: 0.6816
# Epoch [ 6/ 50], Step [ 28/ 78], Loss: 0.6708
# Epoch [ 6/ 50], Step [ 29/ 78], Loss: 0.6658
# Epoch [ 6/ 50], Step [ 30/ 78], Loss: 0.6681
# Epoch [ 6/ 50], Step [ 31/ 78], Loss: 0.6672
# Epoch [ 6/ 50], Step [ 32/ 78], Loss: 0.6704
# Epoch [ 6/ 50], Step [ 33/ 78], Loss: 0.6600
# Epoch [ 6/ 50], Step [ 34/ 78], Loss: 0.6718
# Epoch [ 6/ 50], Step [ 35/ 78], Loss: 0.6903
# Epoch [ 6/ 50], Step [ 36/ 78], Loss: 0.6690
# Epoch [ 6/ 50], Step [ 37/ 78], Loss: 0.6746
# Epoch [ 6/ 50], Step [ 38/ 78], Loss: 0.6764
# Epoch [ 6/ 50], Step [ 39/ 78], Loss: 0.6684
# Epoch [ 6/ 50], Step [ 40/ 78], Loss: 0.6778
# Epoch [ 6/ 50], Step [ 41/ 78], Loss: 0.6650
# Epoch [ 6/ 50], Step [ 42/ 78], Loss: 0.6671
# Epoch [ 6/ 50], Step [ 43/ 78], Loss: 0.6694
# Epoch [ 6/ 50], Step [ 44/ 78], Loss: 0.6699
# Epoch [ 6/ 50], Step [ 45/ 78], Loss: 0.6580
# Epoch [ 6/ 50], Step [ 46/ 78], Loss: 0.6695
# Epoch [ 6/ 50], Step [ 47/ 78], Loss: 0.6787
# Epoch [ 6/ 50], Step [ 48/ 78], Loss: 0.6802
# Epoch [ 6/ 50], Step [ 49/ 78], Loss: 0.6837
# Epoch [ 6/ 50], Step [ 50/ 78], Loss: 0.6701
# Epoch [ 6/ 50], Step [ 51/ 78], Loss: 0.6787
# Epoch [ 6/ 50], Step [ 52/ 78], Loss: 0.6652
# Epoch [ 6/ 50], Step [ 53/ 78], Loss: 0.6742
# Epoch [ 6/ 50], Step [ 54/ 78], Loss: 0.6647
# Epoch [ 6/ 50], Step [ 55/ 78], Loss: 0.6645
# Epoch [ 6/ 50], Step [ 56/ 78], Loss: 0.6583
# Epoch [ 6/ 50], Step [ 57/ 78], Loss: 0.6764
# Epoch [ 6/ 50], Step [ 58/ 78], Loss: 0.6746
# Epoch [ 6/ 50], Step [ 59/ 78], Loss: 0.6762
# Epoch [ 6/ 50], Step [ 60/ 78], Loss: 0.6671
# Epoch [ 6/ 50], Step [ 61/ 78], Loss: 0.6977
# Epoch [ 6/ 50], Step [ 62/ 78], Loss: 0.6662
# Epoch [ 6/ 50], Step [ 63/ 78], Loss: 0.6701
# Epoch [ 7/ 50], Step [  1/ 78], Loss: 0.6797
# Epoch [ 7/ 50], Step [  2/ 78], Loss: 0.6681
# Epoch [ 7/ 50], Step [  3/ 78], Loss: 0.6572
# Epoch [ 7/ 50], Step [  4/ 78], Loss: 0.6722
# Epoch [ 7/ 50], Step [  5/ 78], Loss: 0.6560
# Epoch [ 7/ 50], Step [  6/ 78], Loss: 0.6704
# Epoch [ 7/ 50], Step [  7/ 78], Loss: 0.6703
# Epoch [ 7/ 50], Step [  8/ 78], Loss: 0.6566
# Epoch [ 7/ 50], Step [  9/ 78], Loss: 0.6682
# Epoch [ 7/ 50], Step [ 10/ 78], Loss: 0.6651
# Epoch [ 7/ 50], Step [ 11/ 78], Loss: 0.6899
# Epoch [ 7/ 50], Step [ 12/ 78], Loss: 0.6555
# Epoch [ 7/ 50], Step [ 13/ 78], Loss: 0.6709
# Epoch [ 7/ 50], Step [ 14/ 78], Loss: 0.6608
# Epoch [ 7/ 50], Step [ 15/ 78], Loss: 0.6655
# Epoch [ 7/ 50], Step [ 16/ 78], Loss: 0.6778
# Epoch [ 7/ 50], Step [ 17/ 78], Loss: 0.6628
# Epoch [ 7/ 50], Step [ 18/ 78], Loss: 0.6698
# Epoch [ 7/ 50], Step [ 19/ 78], Loss: 0.6663
# Epoch [ 7/ 50], Step [ 20/ 78], Loss: 0.6668
# Epoch [ 7/ 50], Step [ 21/ 78], Loss: 0.6738
# Epoch [ 7/ 50], Step [ 22/ 78], Loss: 0.6657
# Epoch [ 7/ 50], Step [ 23/ 78], Loss: 0.6705
# Epoch [ 7/ 50], Step [ 24/ 78], Loss: 0.6683
# Epoch [ 7/ 50], Step [ 25/ 78], Loss: 0.6549
# Epoch [ 7/ 50], Step [ 26/ 78], Loss: 0.6810
# Epoch [ 7/ 50], Step [ 27/ 78], Loss: 0.6765
# Epoch [ 7/ 50], Step [ 28/ 78], Loss: 0.6552
# Epoch [ 7/ 50], Step [ 29/ 78], Loss: 0.6746
# Epoch [ 7/ 50], Step [ 30/ 78], Loss: 0.6656
# Epoch [ 7/ 50], Step [ 31/ 78], Loss: 0.6544
# Epoch [ 7/ 50], Step [ 32/ 78], Loss: 0.6828
# Epoch [ 7/ 50], Step [ 33/ 78], Loss: 0.6675
# Epoch [ 7/ 50], Step [ 34/ 78], Loss: 0.6720
# Epoch [ 7/ 50], Step [ 35/ 78], Loss: 0.6653
# Epoch [ 7/ 50], Step [ 36/ 78], Loss: 0.6560
# Epoch [ 7/ 50], Step [ 37/ 78], Loss: 0.6857
# Epoch [ 7/ 50], Step [ 38/ 78], Loss: 0.6787
# Epoch [ 7/ 50], Step [ 39/ 78], Loss: 0.6680
# Epoch [ 7/ 50], Step [ 40/ 78], Loss: 0.6744
# Epoch [ 7/ 50], Step [ 41/ 78], Loss: 0.6646
# Epoch [ 7/ 50], Step [ 42/ 78], Loss: 0.6654
# Epoch [ 7/ 50], Step [ 43/ 78], Loss: 0.6544
# Epoch [ 7/ 50], Step [ 44/ 78], Loss: 0.6744
# Epoch [ 7/ 50], Step [ 45/ 78], Loss: 0.6641
# Epoch [ 7/ 50], Step [ 46/ 78], Loss: 0.6560
# Epoch [ 7/ 50], Step [ 47/ 78], Loss: 0.6634
# Epoch [ 7/ 50], Step [ 48/ 78], Loss: 0.6654
# Epoch [ 7/ 50], Step [ 49/ 78], Loss: 0.6694
# Epoch [ 7/ 50], Step [ 50/ 78], Loss: 0.6753
# Epoch [ 7/ 50], Step [ 51/ 78], Loss: 0.6601
# Epoch [ 7/ 50], Step [ 52/ 78], Loss: 0.6703
# Epoch [ 7/ 50], Step [ 53/ 78], Loss: 0.6622
# Epoch [ 7/ 50], Step [ 54/ 78], Loss: 0.6706
# Epoch [ 7/ 50], Step [ 55/ 78], Loss: 0.6602
# Epoch [ 7/ 50], Step [ 56/ 78], Loss: 0.6607
# Epoch [ 7/ 50], Step [ 57/ 78], Loss: 0.6546
# Epoch [ 7/ 50], Step [ 58/ 78], Loss: 0.6743
# Epoch [ 7/ 50], Step [ 59/ 78], Loss: 0.6616
# Epoch [ 7/ 50], Step [ 60/ 78], Loss: 0.6702
# Epoch [ 7/ 50], Step [ 61/ 78], Loss: 0.6807
# Epoch [ 7/ 50], Step [ 62/ 78], Loss: 0.6768
# Epoch [ 7/ 50], Step [ 63/ 78], Loss: 0.6648
# Epoch [ 8/ 50], Step [  1/ 78], Loss: 0.6575
# Epoch [ 8/ 50], Step [  2/ 78], Loss: 0.6602
# Epoch [ 8/ 50], Step [  3/ 78], Loss: 0.6593
# Epoch [ 8/ 50], Step [  4/ 78], Loss: 0.6583
# Epoch [ 8/ 50], Step [  5/ 78], Loss: 0.6547
# Epoch [ 8/ 50], Step [  6/ 78], Loss: 0.6540
# Epoch [ 8/ 50], Step [  7/ 78], Loss: 0.6675
# Epoch [ 8/ 50], Step [  8/ 78], Loss: 0.6550
# Epoch [ 8/ 50], Step [  9/ 78], Loss: 0.6810
# Epoch [ 8/ 50], Step [ 10/ 78], Loss: 0.6511
# Epoch [ 8/ 50], Step [ 11/ 78], Loss: 0.6566
# Epoch [ 8/ 50], Step [ 12/ 78], Loss: 0.6819
# Epoch [ 8/ 50], Step [ 13/ 78], Loss: 0.6499
# Epoch [ 8/ 50], Step [ 14/ 78], Loss: 0.6482
# Epoch [ 8/ 50], Step [ 15/ 78], Loss: 0.6705
# Epoch [ 8/ 50], Step [ 16/ 78], Loss: 0.6506
# Epoch [ 8/ 50], Step [ 17/ 78], Loss: 0.6468
# Epoch [ 8/ 50], Step [ 18/ 78], Loss: 0.6642
# Epoch [ 8/ 50], Step [ 19/ 78], Loss: 0.6635
# Epoch [ 8/ 50], Step [ 20/ 78], Loss: 0.6693
# Epoch [ 8/ 50], Step [ 21/ 78], Loss: 0.6660
# Epoch [ 8/ 50], Step [ 22/ 78], Loss: 0.6670
# Epoch [ 8/ 50], Step [ 23/ 78], Loss: 0.6614
# Epoch [ 8/ 50], Step [ 24/ 78], Loss: 0.6640
# Epoch [ 8/ 50], Step [ 25/ 78], Loss: 0.6784
# Epoch [ 8/ 50], Step [ 26/ 78], Loss: 0.6866
# Epoch [ 8/ 50], Step [ 27/ 78], Loss: 0.6773
# Epoch [ 8/ 50], Step [ 28/ 78], Loss: 0.6747
# Epoch [ 8/ 50], Step [ 29/ 78], Loss: 0.6761
# Epoch [ 8/ 50], Step [ 30/ 78], Loss: 0.6499
# Epoch [ 8/ 50], Step [ 31/ 78], Loss: 0.6549
# Epoch [ 8/ 50], Step [ 32/ 78], Loss: 0.6724
# Epoch [ 8/ 50], Step [ 33/ 78], Loss: 0.6756
# Epoch [ 8/ 50], Step [ 34/ 78], Loss: 0.6543
# Epoch [ 8/ 50], Step [ 35/ 78], Loss: 0.6606
# Epoch [ 8/ 50], Step [ 36/ 78], Loss: 0.6688
# Epoch [ 8/ 50], Step [ 37/ 78], Loss: 0.6626
# Epoch [ 8/ 50], Step [ 38/ 78], Loss: 0.6742
# Epoch [ 8/ 50], Step [ 39/ 78], Loss: 0.6990
# Epoch [ 8/ 50], Step [ 40/ 78], Loss: 0.6674
# Epoch [ 8/ 50], Step [ 41/ 78], Loss: 0.6693
# Epoch [ 8/ 50], Step [ 42/ 78], Loss: 0.6624
# Epoch [ 8/ 50], Step [ 43/ 78], Loss: 0.6655
# Epoch [ 8/ 50], Step [ 44/ 78], Loss: 0.6428
# Epoch [ 8/ 50], Step [ 45/ 78], Loss: 0.6607
# Epoch [ 8/ 50], Step [ 46/ 78], Loss: 0.6691
# Epoch [ 8/ 50], Step [ 47/ 78], Loss: 0.6649
# Epoch [ 8/ 50], Step [ 48/ 78], Loss: 0.6422
# Epoch [ 8/ 50], Step [ 49/ 78], Loss: 0.6778
# Epoch [ 8/ 50], Step [ 50/ 78], Loss: 0.6730
# Epoch [ 8/ 50], Step [ 51/ 78], Loss: 0.6651
# Epoch [ 8/ 50], Step [ 52/ 78], Loss: 0.6805
# Epoch [ 8/ 50], Step [ 53/ 78], Loss: 0.6771
# Epoch [ 8/ 50], Step [ 54/ 78], Loss: 0.6799
# Epoch [ 8/ 50], Step [ 55/ 78], Loss: 0.6818
# Epoch [ 8/ 50], Step [ 56/ 78], Loss: 0.6405
# Epoch [ 8/ 50], Step [ 57/ 78], Loss: 0.6558
# Epoch [ 8/ 50], Step [ 58/ 78], Loss: 0.6640
# Epoch [ 8/ 50], Step [ 59/ 78], Loss: 0.6611
# Epoch [ 8/ 50], Step [ 60/ 78], Loss: 0.6614
# Epoch [ 8/ 50], Step [ 61/ 78], Loss: 0.6498
# Epoch [ 8/ 50], Step [ 62/ 78], Loss: 0.6737
# Epoch [ 9/ 50], Step [ 45/ 78], Loss: 0.6721
# Epoch [ 9/ 50], Step [ 46/ 78], Loss: 0.6506
# Epoch [ 9/ 50], Step [ 47/ 78], Loss: 0.6689
# Epoch [ 9/ 50], Step [ 48/ 78], Loss: 0.6441
# Epoch [ 9/ 50], Step [ 49/ 78], Loss: 0.6575
# Epoch [ 9/ 50], Step [ 50/ 78], Loss: 0.6503
# Epoch [ 9/ 50], Step [ 51/ 78], Loss: 0.6814
# Epoch [ 9/ 50], Step [ 52/ 78], Loss: 0.6484
# Epoch [ 9/ 50], Step [ 53/ 78], Loss: 0.6670
# Epoch [ 9/ 50], Step [ 54/ 78], Loss: 0.6454
# Epoch [ 9/ 50], Step [ 55/ 78], Loss: 0.6611
# Epoch [ 9/ 50], Step [ 56/ 78], Loss: 0.6338
# Epoch [ 9/ 50], Step [ 57/ 78], Loss: 0.6438
# Epoch [ 9/ 50], Step [ 58/ 78], Loss: 0.6388
# Epoch [ 9/ 50], Step [ 59/ 78], Loss: 0.6557
# Epoch [ 9/ 50], Step [ 60/ 78], Loss: 0.6439
# Epoch [ 9/ 50], Step [ 61/ 78], Loss: 0.6612
# Epoch [ 9/ 50], Step [ 62/ 78], Loss: 0.6505
# Epoch [ 9/ 50], Step [ 63/ 78], Loss: 0.6540
# Epoch [10/ 50], Step [  1/ 78], Loss: 0.6544
# Epoch [10/ 50], Step [  2/ 78], Loss: 0.6694
# Epoch [10/ 50], Step [  3/ 78], Loss: 0.6448
# Epoch [10/ 50], Step [  4/ 78], Loss: 0.6675
# Epoch [10/ 50], Step [  5/ 78], Loss: 0.6562
# Epoch [10/ 50], Step [  6/ 78], Loss: 0.6538
# Epoch [10/ 50], Step [  7/ 78], Loss: 0.6573
# Epoch [10/ 50], Step [  8/ 78], Loss: 0.6563
# Epoch [10/ 50], Step [  9/ 78], Loss: 0.6554
# Epoch [10/ 50], Step [ 10/ 78], Loss: 0.6647
# Epoch [10/ 50], Step [ 11/ 78], Loss: 0.6538
# Epoch [10/ 50], Step [ 12/ 78], Loss: 0.6703
# Epoch [10/ 50], Step [ 13/ 78], Loss: 0.6315
# Epoch [10/ 50], Step [ 14/ 78], Loss: 0.6714
# Epoch [10/ 50], Step [ 15/ 78], Loss: 0.6473
# Epoch [10/ 50], Step [ 16/ 78], Loss: 0.6551
# Epoch [10/ 50], Step [ 17/ 78], Loss: 0.6549
# Epoch [10/ 50], Step [ 18/ 78], Loss: 0.6745
# Epoch [10/ 50], Step [ 19/ 78], Loss: 0.6517
# Epoch [10/ 50], Step [ 20/ 78], Loss: 0.6534
# Epoch [10/ 50], Step [ 21/ 78], Loss: 0.6858
# Epoch [10/ 50], Step [ 22/ 78], Loss: 0.6528
# Epoch [10/ 50], Step [ 23/ 78], Loss: 0.6660
# Epoch [10/ 50], Step [ 24/ 78], Loss: 0.6619
# Epoch [10/ 50], Step [ 25/ 78], Loss: 0.6644
# Epoch [10/ 50], Step [ 26/ 78], Loss: 0.6583
# Epoch [10/ 50], Step [ 27/ 78], Loss: 0.6580
# Epoch [12/ 50], Step [ 43/ 78], Loss: 0.6483
# Epoch [12/ 50], Step [ 44/ 78], Loss: 0.6554
# Epoch [12/ 50], Step [ 45/ 78], Loss: 0.6509
# Epoch [12/ 50], Step [ 46/ 78], Loss: 0.6599
# Epoch [12/ 50], Step [ 47/ 78], Loss: 0.6484
# Epoch [12/ 50], Step [ 48/ 78], Loss: 0.6590
# Epoch [12/ 50], Step [ 49/ 78], Loss: 0.6449
# Epoch [12/ 50], Step [ 50/ 78], Loss: 0.6476
# Epoch [12/ 50], Step [ 51/ 78], Loss: 0.6520
# Epoch [12/ 50], Step [ 52/ 78], Loss: 0.6491
# Epoch [12/ 50], Step [ 53/ 78], Loss: 0.6344
# Epoch [12/ 50], Step [ 54/ 78], Loss: 0.6352
# Epoch [12/ 50], Step [ 55/ 78], Loss: 0.6565
# Epoch [12/ 50], Step [ 56/ 78], Loss: 0.6428
# Epoch [12/ 50], Step [ 57/ 78], Loss: 0.6653
# Epoch [12/ 50], Step [ 58/ 78], Loss: 0.6385
# Epoch [12/ 50], Step [ 59/ 78], Loss: 0.6618
# Epoch [12/ 50], Step [ 60/ 78], Loss: 0.6439
# Epoch [12/ 50], Step [ 61/ 78], Loss: 0.6635
# Epoch [12/ 50], Step [ 62/ 78], Loss: 0.6408
# Epoch [12/ 50], Step [ 63/ 78], Loss: 0.6396
# Epoch [13/ 50], Step [  1/ 78], Loss: 0.6465
# Epoch [13/ 50], Step [  2/ 78], Loss: 0.6488
# Epoch [13/ 50], Step [  3/ 78], Loss: 0.6379
# Epoch [13/ 50], Step [  4/ 78], Loss: 0.6657
# Epoch [13/ 50], Step [  5/ 78], Loss: 0.6510
# Epoch [13/ 50], Step [  6/ 78], Loss: 0.6163
# Epoch [13/ 50], Step [  7/ 78], Loss: 0.6678
# Epoch [13/ 50], Step [  8/ 78], Loss: 0.6630
# Epoch [13/ 50], Step [  9/ 78], Loss: 0.6424
# Epoch [13/ 50], Step [ 10/ 78], Loss: 0.6385
# Epoch [13/ 50], Step [ 11/ 78], Loss: 0.6719
# Epoch [13/ 50], Step [ 12/ 78], Loss: 0.6407
# Epoch [13/ 50], Step [ 13/ 78], Loss: 0.6201
# Epoch [13/ 50], Step [ 14/ 78], Loss: 0.6529
# Epoch [13/ 50], Step [ 15/ 78], Loss: 0.6549
# Epoch [13/ 50], Step [ 16/ 78], Loss: 0.6789
# Epoch [13/ 50], Step [ 17/ 78], Loss: 0.6570
# Epoch [13/ 50], Step [ 18/ 78], Loss: 0.6535
# Epoch [13/ 50], Step [ 19/ 78], Loss: 0.6541
# Epoch [13/ 50], Step [ 20/ 78], Loss: 0.6574
# Epoch [13/ 50], Step [ 21/ 78], Loss: 0.6542
# Epoch [13/ 50], Step [ 22/ 78], Loss: 0.6456
# Epoch [13/ 50], Step [ 23/ 78], Loss: 0.6498
# Epoch [13/ 50], Step [ 24/ 78], Loss: 0.6466
# Epoch [13/ 50], Step [ 25/ 78], Loss: 0.6196
# Epoch [13/ 50], Step [ 26/ 78], Loss: 0.6224
# Epoch [13/ 50], Step [ 27/ 78], Loss: 0.6790
# Epoch [15/ 50], Step [ 43/ 78], Loss: 0.6514
# Epoch [15/ 50], Step [ 44/ 78], Loss: 0.6552
# Epoch [15/ 50], Step [ 45/ 78], Loss: 0.6500
# Epoch [15/ 50], Step [ 46/ 78], Loss: 0.6430
# Epoch [15/ 50], Step [ 47/ 78], Loss: 0.6408
# Epoch [15/ 50], Step [ 48/ 78], Loss: 0.6407
# Epoch [15/ 50], Step [ 49/ 78], Loss: 0.6391
# Epoch [15/ 50], Step [ 50/ 78], Loss: 0.6347
# Epoch [15/ 50], Step [ 51/ 78], Loss: 0.6560
# Epoch [15/ 50], Step [ 52/ 78], Loss: 0.6407
# Epoch [15/ 50], Step [ 53/ 78], Loss: 0.6430
# Epoch [15/ 50], Step [ 54/ 78], Loss: 0.6405
# Epoch [15/ 50], Step [ 55/ 78], Loss: 0.6211
# Epoch [15/ 50], Step [ 56/ 78], Loss: 0.6512
# Epoch [15/ 50], Step [ 57/ 78], Loss: 0.6550
# Epoch [15/ 50], Step [ 58/ 78], Loss: 0.6711
# Epoch [15/ 50], Step [ 59/ 78], Loss: 0.6429
# Epoch [15/ 50], Step [ 60/ 78], Loss: 0.6520
# Epoch [15/ 50], Step [ 61/ 78], Loss: 0.6443
# Epoch [15/ 50], Step [ 62/ 78], Loss: 0.6634
# Epoch [15/ 50], Step [ 63/ 78], Loss: 0.6493
# Epoch [16/ 50], Step [  1/ 78], Loss: 0.6908
# Epoch [16/ 50], Step [  2/ 78], Loss: 0.6456
# Epoch [16/ 50], Step [  3/ 78], Loss: 0.6334
# Epoch [16/ 50], Step [  4/ 78], Loss: 0.6330
# Epoch [16/ 50], Step [  5/ 78], Loss: 0.6278
# Epoch [16/ 50], Step [  6/ 78], Loss: 0.6498
# Epoch [16/ 50], Step [  7/ 78], Loss: 0.6252
# Epoch [16/ 50], Step [  8/ 78], Loss: 0.6366
# Epoch [16/ 50], Step [  9/ 78], Loss: 0.6298
# Epoch [16/ 50], Step [ 10/ 78], Loss: 0.6354
# Epoch [16/ 50], Step [ 11/ 78], Loss: 0.6428
# Epoch [16/ 50], Step [ 12/ 78], Loss: 0.6243
# Epoch [16/ 50], Step [ 13/ 78], Loss: 0.6447
# Epoch [16/ 50], Step [ 14/ 78], Loss: 0.6540
# Epoch [16/ 50], Step [ 15/ 78], Loss: 0.6471
# Epoch [16/ 50], Step [ 16/ 78], Loss: 0.6609
# Epoch [16/ 50], Step [ 17/ 78], Loss: 0.6189
# Epoch [16/ 50], Step [ 18/ 78], Loss: 0.6243
# Epoch [16/ 50], Step [ 19/ 78], Loss: 0.6547
# Epoch [16/ 50], Step [ 20/ 78], Loss: 0.6560
# Epoch [16/ 50], Step [ 21/ 78], Loss: 0.6451
# Epoch [16/ 50], Step [ 22/ 78], Loss: 0.6386
# Epoch [16/ 50], Step [ 23/ 78], Loss: 0.6337
# Epoch [16/ 50], Step [ 24/ 78], Loss: 0.6336
# Epoch [16/ 50], Step [ 25/ 78], Loss: 0.6465
# Epoch [16/ 50], Step [ 26/ 78], Loss: 0.6593
# Epoch [16/ 50], Step [ 27/ 78], Loss: 0.6640
# Epoch [16/ 50], Step [ 28/ 78], Loss: 0.6477
# Epoch [16/ 50], Step [ 29/ 78], Loss: 0.6351
# Epoch [16/ 50], Step [ 30/ 78], Loss: 0.6490
# Epoch [16/ 50], Step [ 31/ 78], Loss: 0.6478
# Epoch [16/ 50], Step [ 32/ 78], Loss: 0.6216
# Epoch [16/ 50], Step [ 33/ 78], Loss: 0.6598
# Epoch [16/ 50], Step [ 34/ 78], Loss: 0.6159
# Epoch [16/ 50], Step [ 35/ 78], Loss: 0.6182
# Epoch [16/ 50], Step [ 36/ 78], Loss: 0.6070
# Epoch [16/ 50], Step [ 37/ 78], Loss: 0.6316
# Epoch [16/ 50], Step [ 38/ 78], Loss: 0.6342
# Epoch [16/ 50], Step [ 39/ 78], Loss: 0.6227
# Epoch [16/ 50], Step [ 40/ 78], Loss: 0.6639
# Epoch [16/ 50], Step [ 41/ 78], Loss: 0.6368
# Epoch [16/ 50], Step [ 42/ 78], Loss: 0.6516
# Epoch [16/ 50], Step [ 43/ 78], Loss: 0.6517
# Epoch [16/ 50], Step [ 44/ 78], Loss: 0.6481
# Epoch [16/ 50], Step [ 45/ 78], Loss: 0.6419
# Epoch [16/ 50], Step [ 46/ 78], Loss: 0.6259
# Epoch [16/ 50], Step [ 47/ 78], Loss: 0.6669
# Epoch [16/ 50], Step [ 48/ 78], Loss: 0.6613
# Epoch [16/ 50], Step [ 49/ 78], Loss: 0.6332
# Epoch [16/ 50], Step [ 50/ 78], Loss: 0.6455
# Epoch [16/ 50], Step [ 51/ 78], Loss: 0.6341
# Epoch [16/ 50], Step [ 52/ 78], Loss: 0.6725
# Epoch [16/ 50], Step [ 53/ 78], Loss: 0.6011
# Epoch [16/ 50], Step [ 54/ 78], Loss: 0.6503
# Epoch [16/ 50], Step [ 55/ 78], Loss: 0.6386
# Epoch [16/ 50], Step [ 56/ 78], Loss: 0.6264
# Epoch [16/ 50], Step [ 57/ 78], Loss: 0.6405
# Epoch [16/ 50], Step [ 58/ 78], Loss: 0.6368
# Epoch [16/ 50], Step [ 59/ 78], Loss: 0.6218
# Epoch [16/ 50], Step [ 60/ 78], Loss: 0.6364
# Epoch [16/ 50], Step [ 61/ 78], Loss: 0.6420
# Epoch [16/ 50], Step [ 62/ 78], Loss: 0.6201
# Epoch [16/ 50], Step [ 63/ 78], Loss: 0.6459
# Epoch [17/ 50], Step [  1/ 78], Loss: 0.6502
# Epoch [17/ 50], Step [  2/ 78], Loss: 0.6340
# Epoch [17/ 50], Step [  3/ 78], Loss: 0.6589
# Epoch [17/ 50], Step [  4/ 78], Loss: 0.6252
# Epoch [17/ 50], Step [  5/ 78], Loss: 0.6394
# Epoch [17/ 50], Step [  6/ 78], Loss: 0.6504
# Epoch [17/ 50], Step [  7/ 78], Loss: 0.6458
# Epoch [17/ 50], Step [  8/ 78], Loss: 0.6153
# Epoch [17/ 50], Step [  9/ 78], Loss: 0.6409
# Epoch [17/ 50], Step [ 10/ 78], Loss: 0.6405
# Epoch [49/ 50], Step [ 12/ 78], Loss: 0.5998
# Epoch [49/ 50], Step [ 13/ 78], Loss: 0.5597
# Epoch [49/ 50], Step [ 14/ 78], Loss: 0.5755
# Epoch [49/ 50], Step [ 15/ 78], Loss: 0.5610
# Epoch [49/ 50], Step [ 16/ 78], Loss: 0.5659
# Epoch [49/ 50], Step [ 17/ 78], Loss: 0.5726
# Epoch [49/ 50], Step [ 18/ 78], Loss: 0.5889
# Epoch [49/ 50], Step [ 19/ 78], Loss: 0.6020
# Epoch [49/ 50], Step [ 20/ 78], Loss: 0.5402
# Epoch [49/ 50], Step [ 21/ 78], Loss: 0.5756
# Epoch [49/ 50], Step [ 22/ 78], Loss: 0.5723
# Epoch [49/ 50], Step [ 23/ 78], Loss: 0.5666
# Epoch [49/ 50], Step [ 24/ 78], Loss: 0.5431
# Epoch [49/ 50], Step [ 25/ 78], Loss: 0.5695
# Epoch [49/ 50], Step [ 26/ 78], Loss: 0.5776
# Epoch [49/ 50], Step [ 27/ 78], Loss: 0.5851
# Epoch [49/ 50], Step [ 28/ 78], Loss: 0.5321
# Epoch [49/ 50], Step [ 29/ 78], Loss: 0.5700
# Epoch [49/ 50], Step [ 30/ 78], Loss: 0.5583
# Epoch [49/ 50], Step [ 31/ 78], Loss: 0.5559
# Epoch [49/ 50], Step [ 32/ 78], Loss: 0.5395
# Epoch [49/ 50], Step [ 33/ 78], Loss: 0.5662
# Epoch [49/ 50], Step [ 34/ 78], Loss: 0.5451
# Epoch [49/ 50], Step [ 35/ 78], Loss: 0.5396
# Epoch [49/ 50], Step [ 36/ 78], Loss: 0.5681
# Epoch [49/ 50], Step [ 37/ 78], Loss: 0.5516
# Epoch [49/ 50], Step [ 38/ 78], Loss: 0.5548
# Epoch [49/ 50], Step [ 39/ 78], Loss: 0.5719
# Epoch [49/ 50], Step [ 40/ 78], Loss: 0.5760
# Epoch [49/ 50], Step [ 41/ 78], Loss: 0.5973
# Epoch [49/ 50], Step [ 42/ 78], Loss: 0.5725
# Epoch [49/ 50], Step [ 43/ 78], Loss: 0.5794
# Epoch [49/ 50], Step [ 44/ 78], Loss: 0.5662
# Epoch [49/ 50], Step [ 45/ 78], Loss: 0.5533
# Epoch [49/ 50], Step [ 46/ 78], Loss: 0.5390
# Epoch [49/ 50], Step [ 47/ 78], Loss: 0.5547
# Epoch [49/ 50], Step [ 48/ 78], Loss: 0.5918
# Epoch [49/ 50], Step [ 49/ 78], Loss: 0.5562
# Epoch [49/ 50], Step [ 50/ 78], Loss: 0.5805
# Epoch [49/ 50], Step [ 51/ 78], Loss: 0.6261
# Epoch [49/ 50], Step [ 52/ 78], Loss: 0.5998
# Epoch [49/ 50], Step [ 53/ 78], Loss: 0.5363
# Epoch [49/ 50], Step [ 54/ 78], Loss: 0.5821
# Epoch [49/ 50], Step [ 55/ 78], Loss: 0.5692
# Epoch [49/ 50], Step [ 56/ 78], Loss: 0.5453
# Epoch [49/ 50], Step [ 57/ 78], Loss: 0.5500
# Epoch [49/ 50], Step [ 58/ 78], Loss: 0.5500
# Epoch [50/ 50], Step [ 43/ 78], Loss: 0.5731
# Epoch [50/ 50], Step [ 44/ 78], Loss: 0.5842
# Epoch [50/ 50], Step [ 45/ 78], Loss: 0.5491
# Epoch [50/ 50], Step [ 46/ 78], Loss: 0.6012
# Epoch [50/ 50], Step [ 47/ 78], Loss: 0.5999
# Epoch [50/ 50], Step [ 48/ 78], Loss: 0.5493
# Epoch [50/ 50], Step [ 49/ 78], Loss: 0.5448
# Epoch [50/ 50], Step [ 50/ 78], Loss: 0.5588
# Epoch [50/ 50], Step [ 51/ 78], Loss: 0.5506
# Epoch [50/ 50], Step [ 52/ 78], Loss: 0.5955
# Epoch [50/ 50], Step [ 53/ 78], Loss: 0.5562
# Epoch [50/ 50], Step [ 54/ 78], Loss: 0.5595
# Epoch [50/ 50], Step [ 55/ 78], Loss: 0.5383
# Epoch [50/ 50], Step [ 56/ 78], Loss: 0.5449
# Epoch [50/ 50], Step [ 57/ 78], Loss: 0.5576
# Epoch [50/ 50], Step [ 58/ 78], Loss: 0.5915
# Epoch [50/ 50], Step [ 59/ 78], Loss: 0.6005
# Epoch [50/ 50], Step [ 60/ 78], Loss: 0.5807
# Epoch [50/ 50], Step [ 61/ 78], Loss: 0.5656
# Epoch [50/ 50], Step [ 62/ 78], Loss: 0.5864
# Epoch [50/ 50], Step [ 63/ 78], Loss: 0.5722

# %%
plt.figure(figsize=(12, 4))
plt.plot(epoch_losses)
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('Cross Entropy loss')
# Out:
# Text(0.5, 1.0, 'Cross Entropy loss')

# %%
# def evaluate_model(model, DataLoader):
#     model.eval()  # for batch norm layer
correct = 0
total = 0
with torch.no_grad():
    for data in valid_dl:
        images, labels = data
        images = to_var(images)
        labels = to_var(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the valid images: %d %%' % (100 * correct / total))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Accuracy of the network on the valid images: 71 %

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in train_dl:
        images, labels = data
        images = to_var(images)
        labels = to_var(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the train images: %d %%' % (100 * correct / total))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Accuracy of the network on the train images: 73 %

# %%
correct = 0
total = 0
predictions = []
with torch.no_grad():
    for data in test_dl:
        images, labels = data
        images = to_var(images)
        labels = to_var(labels)
        outputs = model(images)
        predictions.append(outputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Accuracy of the network on the test images: 44 %

# %% [markdown]
# # Submit the results

# %%
def predictCSV(predicts, file_path):
  labels = {0:'Cat', 1:'Dog'}
  with open(file_path,'w',newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(("id","label"))
    for i, label in enumerate(predicts):
#       _, predict = torch.max(predicts[i].data, 0)
#       print(int(predicts[i].data[0]))
      writer.writerow((i+1,labels[int(predicts[i].data[0])]))
#   debug("save predict csv files of model to :{}".format(file_path))

# print(predictions)
predictCSV(predictions,"kaggle.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-47594607678c> in <module>()
#      11
#      12 # print(predictions)
# ---> 13 predictCSV(predictions,"kaggle.csv")
#      14
#      15
#
# <ipython-input-33-47594607678c> in predictCSV(predicts, file_path)
#       7 #       _, predict = torch.max(predicts[i].data, 0)
#       8 #       print(int(predicts[i].data[0]))
# ----> 9       writer.writerow((i+1,labels[int(predicts[i].data[0])]))
#      10 #   debug("save predict csv files of model to :{}".format(file_path))
#      11
#
# ValueError: only one element tensors can be converted to Python scalars
